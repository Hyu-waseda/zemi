# %% [markdown]
# <a href="https://colab.research.google.com/github/Hyu-waseda/zemi/blob/main/time_series_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install fbprophet

# %%
import pandas as pd
from fbprophet import Prophet
from fbprophet import plot
from fbprophet.diagnostics import cross_validation, performance_metrics

# %% [markdown]
# 日経平均

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('./zikeiretubunseki_owarine.csv')

# %%
df.head()
# Out:
#             ds          y         始値         高値         安値      出来高   変化率 %
# 0  2022年06月24日  26,491.97  26,228.42  26,519.16  26,148.56  726.41M   1.23%
# 1  2022年06月23日  26,171.25  26,134.89  26,401.97  26,039.57  656.83M   0.08%
# 2  2022年06月22日  26,149.55  26,441.72  26,462.83  26,149.17  663.69M  -0.37%
# 3  2022年06月21日  26,246.31  26,070.92  26,418.84  25,972.28  653.59M   1.84%
# 4  2022年06月20日  25,771.22  26,156.62  26,156.62  25,520.23  721.76M  -0.74%

# %%
#年月日のフォーマット変更
for i in range(len(df["ds"])):
  df["ds"][i] = df["ds"][i].replace("年", "-")
  df["ds"][i] = df["ds"][i].replace("月", "-")
  df["ds"][i] = df["ds"][i].replace("日", "")

#終値のフォーマット変更終値のフォーマット変更
for i in range(len(df["y"])):
  df["y"][i] = df["y"][i].replace(",", "")

# %%
# 予測モデルの作成
from fbprophet import Prophet
model = Prophet()
model.fit(df)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
# 2年の空のデータフレームを用意
future_df = model.make_future_dataframe(730)
future_df.tail()
# Out:
#              ds
# 5672 2024-06-19
# 5673 2024-06-20
# 5674 2024-06-21
# 5675 2024-06-22
# 5676 2024-06-23

# %%
forecast_df = model.predict(future_df)
forecast_df[["ds", "yhat"]]
# Out:
#              ds          yhat
# 0    2002-05-27  10085.532796
# 1    2002-05-28  10089.765086
# 2    2002-05-29  10101.834918
# 3    2002-05-30  10096.799044
# 4    2002-05-31  10110.559665
# ...         ...           ...
# 5672 2024-06-19  32159.201767
# 5673 2024-06-20  32149.587241
# 5674 2024-06-21  32160.436187
# 5675 2024-06-22  33067.507822
# 5676 2024-06-23  31997.215233
#
# [5677 rows x 2 columns]

# %%
# plotlyでプロット
from fbprophet import plot
plot.plot_plotly(model, forecast_df)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# 要素別の予測値プロット
plot.plot_components_plotly(model, forecast_df)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 平均気温

# %%
df = pd.read_csv('./zikeiretubunseki_kion.csv')

# %%
df.head()
# Out:
#           ds     y
# 0  2012/6/25  17.0
# 1  2012/6/26  19.1
# 2  2012/6/27  19.6
# 3  2012/6/28  20.4
# 4  2012/6/29  22.4

# %%
# 予測モデルの作成
from fbprophet import Prophet
model = Prophet()
model.fit(df)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
# 2年の空のデータフレームを用意
future_df = model.make_future_dataframe(730)
future_df.tail()
# Out:
#              ds
# 4378 2024-06-20
# 4379 2024-06-21
# 4380 2024-06-22
# 4381 2024-06-23
# 4382 2024-06-24

# %%
forecast_df = model.predict(future_df)
forecast_df[["ds", "yhat"]]
# Out:
#              ds       yhat
# 0    2012-06-25  22.143738
# 1    2012-06-26  22.297240
# 2    2012-06-27  22.283122
# 3    2012-06-28  22.384591
# 4    2012-06-29  22.555277
# ...         ...        ...
# 4378 2024-06-20  20.718933
# 4379 2024-06-21  20.838850
# 4380 2024-06-22  20.912620
# 4381 2024-06-23  21.075283
# 4382 2024-06-24  21.284835
#
# [4383 rows x 2 columns]

# %%
# plotlyでプロット
from fbprophet import plot
plot.plot_plotly(model, forecast_df)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# 要素別の予測値プロット
plot.plot_components_plotly(model, forecast_df)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
